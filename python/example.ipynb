# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: ANYWIDGET_HMR=1

# %%
mv.request('system.box.set_orthogonal_box', lengths=[5, 5, 5], origin=[0,0,0], direction=[0,0,0])
# Out:
# Requesting system.box.set_orthogonal_box with {'lengths': [5, 5, 5], 'origin': [0, 0, 0], 'direction': [0, 0, 0]}

# %%
mv.request('system.box.draw')
# Out:
# Requesting system.box.draw with {}

# %%
mv.do('system.frame', 'add_atom', name='C', x=0, y=0, z=0)

# %%
mv.do('system.frame', 'add_atom', name='C', x=1, y=1, z=1)

# %%
mv.do('system.frame', 'draw')
