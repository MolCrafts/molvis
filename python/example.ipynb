# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
# Out:
# env: ANYWIDGET_HMR=1

# %%
from src.widget import MolvisWidget
mv = MolvisWidget()
mv
# Out:
# MolvisWidget(target='', method='', kwargs={})

# %%
mv.do('system.box', 'set_orthogonal_box', lengths=[5, 5, 5], origin=[0,0,0], direction=[0,0,0])

# %%
mv.do('system.box', 'draw')

# %%
mv.do('system.frame', 'add_atom', name='C', x=0, y=0, z=0)

# %%
mv.do('system.frame', 'add_atom', name='C', x=1, y=1, z=1)

# %%
mv.do('system.frame', 'draw')
